# %%
import pandas as pd

data = {
    "Name": ["Rohit", "Amit", "Sneha", "Priya", "Karan"],
    "Age": [20, 21, 19, 22, 20],
    "Branch": ["CE", "IT", "CE", "ENTC", "IT"],
    "Marks": [85, 78, 92, 88, 76],
    "City": ["Pune", "Mumbai", "Pune", "Nashik", "Pune"]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Name  Age Branch  Marks    City
# 0  Rohit   20     CE     85    Pune
# 1   Amit   21     IT     78  Mumbai
# 2  Sneha   19     CE     92    Pune
# 3  Priya   22   ENTC     88  Nashik
# 4  Karan   20     IT     76    Pune

# %%
df.head(3)
# Out:
#     Name  Age Branch  Marks    City
# 0  Rohit   20     CE     85    Pune
# 1   Amit   21     IT     78  Mumbai
# 2  Sneha   19     CE     92    Pune

# %%
df.tail(2)
# Out:
#     Name  Age Branch  Marks    City
# 3  Priya   22   ENTC     88  Nashik
# 4  Karan   20     IT     76    Pune

# %%
df.shape
# Out:
# (5, 5)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Branch', 'Marks', 'City'], dtype='object')

# %%
df[["Name" , "Marks" ]]
# Out:
#     Name  Marks
# 0  Rohit     85
# 1   Amit     78
# 2  Sneha     92
# 3  Priya     88
# 4  Karan     76

# %%
df[["Name" , "Marks"]][df["Marks"] > 80]
# Out:
#     Name  Marks
# 0  Rohit     85
# 2  Sneha     92
# 3  Priya     88

# %%
df.query("City == 'Pune'")
# Out:
#     Name  Age Branch  Marks  City
# 0  Rohit   20     CE     85  Pune
# 2  Sneha   19     CE     92  Pune
# 4  Karan   20     IT     76  Pune

# %%
df[(df["Branch"] == "IT") & (df["Marks"] > 80)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Branch, Marks, City]
# Index: []

# %%
df.count()
# Out:
# Name      5
# Age       5
# Branch    5
# Marks     5
# City      5
# dtype: int64

# %%
df["Age"].min()
# Out:
# 19

# %%
df["Branch"].count()
# Out:
# np.int64(5)

# %%
df_sorted = df.sort_values(by="Marks", ascending=False).copy()
df_sorted
# Out:
#     Name  Age Branch  Marks    City
# 2  Sneha   19     CE     92    Pune
# 3  Priya   22   ENTC     88  Nashik
# 0  Rohit   20     CE     85    Pune
# 1   Amit   21     IT     78  Mumbai
# 4  Karan   20     IT     76    Pune
